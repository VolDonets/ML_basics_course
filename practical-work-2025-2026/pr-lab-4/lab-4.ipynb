# %% [markdown]
# # Instruction to lab work # 4: Clustering & Dim reduction
#
# > Student name    - Volodymyr
#
# > Student surname - Donets
#
# > Group           - KU-31

# %% [markdown]
# # Description of the work
#
# ## Theory on dimension reduction methods
#
# * [PCA](https://en.wikipedia.org/wiki/Principal_component_analysis)
# * [t-SNE](https://en.wikipedia.org/wiki/T-distributed_stochastic_neighbor_embedding)
# * [UMAP](https://en.wikipedia.org/wiki/Nonlinear_dimensionality_reduction#Uniform_manifold_approximation_and_projection)
#
# * [YouTube Playlist PCA, t-SNE, UMAP how it works](https://www.youtube.com/watch?v=jc1_yPYmspk&list=PLV8yxwGOxvvoJ87mFL27k7XSDq_lF3pD5)
# * [PCA core: SVD](https://www.youtube.com/watch?v=nbBvuuNVfco)
#
# ### Estimating quality of dimension reduction:
#
# * For PCA: `explained variance ratio` np.sum(pca.explained_variance_ratio_)
# * For other methods there is no built-in methods for estimating dimension reduction quality, but you can do this with incorporating with other ML methods like classification for labeled methods and estimating clustering quality on dimensionally reduced methods.
#
# ## Theory on clustering methods
#
# * [Sklearn clustering methods comparison](https://scikit-learn.org/stable/modules/clustering.html)
# * [k-means](https://en.wikipedia.org/wiki/K-means_clustering)
# * [Spectral Clustering overview](https://arxiv.org/html/2501.13597v2)
# * [Spectral Clustering Kaggle](https://www.kaggle.com/code/vipulgandhi/spectral-clustering-detailed-explanation)
# * [Agglomerative (Hierarchical) Clustering](https://medium.com/@prasanth32888/agglomerative-hierarchical-clustering-ahc-e9e7a48cb042)
# * [DBSCAN](https://medium.com/@sachinsoni600517/clustering-like-a-pro-a-beginners-guide-to-dbscan-6c8274c362c4)
#
#
# ### Estimating quality of resulting clusters
#
# * WCSS (Within Cluster Sum of Squares) Use it Only with k-means. []()
# * [Silhouette Score](https://en.wikipedia.org/wiki/Silhouette_(clustering)) -- The silhouette value ranges from −1 to +1, where a high value indicates that the object is well matched to its own cluster and poorly matched to neighboring clusters. If most objects have a high value, then the clustering configuration is appropriate. If many points have a low or negative value, then the clustering configuration may have too many or too few clusters. __A clustering with an average silhouette width of over 0.7 is considered to be "strong", a value over 0.5 "reasonable", and over 0.25 "weak".__
# * [Calinski-Harabasz Score](https://en.wikipedia.org/wiki/Calinski%E2%80%93Harabasz_index) -- higher Calinski-Harabasz score relates to a model with better defined clusters
# * [David Bouldin Score](https://en.wikipedia.org/wiki/Davies%E2%80%93Bouldin_index) -- lower Davies-Bouldin index relates to a model with better separation between the clusters
# * [Clustering quality estimating metrics available in Sklearn](https://scikit-learn.org/stable/modules/clustering.html#clustering-performance-evaluation)
# * [Density-based clustering validation](https://en.wikipedia.org/wiki/Density-based_clustering_validation) this is similar to Silhouette score.
# * `Normalized Mutual Information (NMI)`: Measures the agreement between the true labels and the clustering-assigned labels. A score of 1.0 is a perfect match.
# * `Adjusted Rand Index (ARI)`: Measures the similarity between two clusterings (in this case, your cluster_labels and the true_labels), correcting for chance. A score of 1.0 is perfect.
# * `Fowlkes-Mallows Score`: Similar to ARI, it's the geometric mean of precision and recall.
#
#
# ## Datasets to use (just use that one from the 2nd lab work)
#
# 1. [Liver Cirrhosis Stage Classification](https://www.kaggle.com/datasets/aadarshvelu/liver-cirrhosis-stage-classification)
# 2. [Star Dataset for Stellar Classification](https://www.kaggle.com/datasets/vinesmsuic/star-categorization-giants-and-dwarfs)
# 3. [Fitness Classification Dataset](https://www.kaggle.com/datasets/muhammedderric/fitness-classification-dataset-synthetic)
# 4. [ECG Arrhythmia Classification Dataset](https://www.kaggle.com/datasets/sadmansakib7/ecg-arrhythmia-classification-dataset)
# 5. [Mushroom Classification Enhanced](https://www.kaggle.com/datasets/sakurapuare/mushroom-classification-enhanced)
# 6. [Dry Bean Dataset Classification](https://www.kaggle.com/datasets/nimapourmoradi/dry-bean-dataset-classification)
# 7. [Swarm Behaviour Classification](https://www.kaggle.com/datasets/deepcontractor/swarm-behaviour-classification) -- challenging one 270 Mb dataset
# 8. [Anemia Types Classification](https://www.kaggle.com/datasets/ehababoelnaga/anemia-types-classification)
# 9. [NASA: Asteroids Classification](https://www.kaggle.com/datasets/shrutimehta/nasa-asteroids-classification)
#
# ## Task description
#
# 1. Data Preparation (similar to all our previous lab works):
#     * Load your dataset.
#     * Separate your features (X) and your target/true class label (y).
#     * Pre-process your features (X)! Almost all these algorithms require data to be on the same scale. Use `sklearn.preprocessing.StandardScaler` or `MinMaxScaler` on your feature data (X).
# 2. Baseline Clustering (Original Data):
#     * Perform clustering on your full-dimensional, scaled data (X).
#     * Use all proposed methods (`k-means`, `DBSCAN`, `Agglomerative` & `Spectral`).
#     * Tune the hyperparameters for each.
#     * Evaluate these baseline clusters.
#         * Unsupervised evaluation: Calculate `WCSS` only for k-means; `Silhouette score` & `Davis-Bouldin index` & `Calinski-Harabasz score` for "sphere"-based methods; `number of clusters` & `number of outliers` for DBSCAN.
#         * Supervised evaluation: Compare your cluster labels to the true labels (y) using `NMI`, `ARI` & `Fowlkes-Mallows scores`. This is your "baseline" score.
# 3. Dimensionality Reduction & Visualization:
#     * Apply PCA, t-SNE, and UMAP to your scaled data (X) to reduce it to 2 and 3 components.
#     * Visualize: Create a 2D and 3D scatter plots for each (PCA, t-SNE, UMAP). Color the points using the true class labels (y). This shows you how well the DR method visually separates the real classes.
#     * Evaluate DR: Calculate the `explained_variance_ratio_` for PCA and `trustworthiness` for t-SNE and UMAP.
# 4. Clustering on Reduced Data:
#     * Now, perform clustering again, but this time on your low-dimensional datasets (e.g., on the 2D data from PCA and the 2D data from UMAP).
#     * Use the same clustering algorithms and hyperparameter tuning as in Step 2.
#     * Evaluate these new clusters using the same unsupervised (`Silhouette`) and supervised (`ARI`, `NMI`) metrics.
# 5. Analysis and Conclusion:
#     * Create a table or write a summary comparing your results.
#     * Did the clustering scores (`Silhouette`, `ARI`) improve or get worse after DR?
#     * Did the data from UMAP cluster "better" than the data from PCA?
#     * How did the visual separation you saw in Step 3 plots correspond to the clustering scores?
#     * Which clustering algorithm (e.g., k-means, DBSCAN) worked best for this dataset, both before and after reduction?
# 6. BONUS Task (+2 points):
#     * [DBCV (Density-Based Clustering Validation)](https://en.wikipedia.org/wiki/Density-based_clustering_validation), a metric similar to Silhouette but designed for density-based clusters (like DBSCAN) as it doesn't need cluster centers.
#     * Implement the `DBCV` score from the article (or find a Python library that has it, e.g., `hdbscan.validity.density_based_clustering_validation`) and use it to evaluate the quality of your `DBSCAN` results. Compare its score to the `Silhouette score` (which often performs poorly for `DBSCAN`).

# %% [markdown]
# # Import dependencies

# %%
# RUN the cell, if you do NOT have required libs
# !pip install numpy
# !pip install pandas

# !pip install matplotlib
# !pip install seaborn
# !pip install plotly

# !pip install scikit-learn
# !pip install umap-learn
# !pip install hdbscan

# !pip install tqdm

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap

from sklearn.cluster import (
    KMeans, 
    DBSCAN, 
    AgglomerativeClustering, 
    SpectralClustering
)

# DR Quality
from sklearn.manifold import trustworthiness

# Unsupervised Clustering Quality (no true labels)
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import calinski_harabasz_score

# Supervised Clustering Quality (using true labels, your step 6)
from sklearn.metrics import normalized_mutual_info_score
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics import fowlkes_mallows_score
from sklearn.metrics import confusion_matrix

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

from tqdm import tqdm


# %matplotlib inline

# %% [markdown]
# # Some useful code

# %%
def plot_2d(X_2d, labels, title="2D Visualization"):
    """
    Creates a 2D scatter plot of reduced data, colored by labels.

    Args:
        X_2d (np.array): Data reduced to 2 components (shape [n_samples, 2]).
        labels (np.array): The labels for each sample (shape [n_samples,]).
        title (str): The title for the plot.
    """
    
    plt.figure(figsize=(10, 7))
    sns.scatterplot(
        x=X_2d[:, 0], 
        y=X_2d[:, 1],
        hue=labels,
        palette=sns.color_palette("bright", n_colors=len(np.unique(labels))),
        legend="full"
    )
    plt.title(title)
    plt.xlabel("Component 1")
    plt.ylabel("Component 2")
    plt.show()

# %%
def plot_3d_plotly(X_3d, labels, title="3D Visualization"):
    """
    Creates an interactive 3D scatter plot of reduced data, colored by labels.

    Args:
        X_3d (np.array): Data reduced to 3 components (shape [n_samples, 3]).
        labels (np.array): The labels for each sample (shape [n_samples,]).
        title (str): The title for the plot.
    """
    
    # Create a DataFrame for Plotly Express
    df = pd.DataFrame({
        'Component 1': X_3d[:, 0],
        'Component 2': X_3d[:, 1],
        'Component 3': X_3d[:, 2],
        'label': labels
    })
    
    # IMPORTANT: Convert labels to string to ensure Plotly treats them
    # as discrete categories for coloring.
    df['label'] = df['label'].astype(str)
    
    fig = px.scatter_3d(
        df, 
        x='Component 1', 
        y='Component 2', 
        z='Component 3',
        color='label',  # Color points by the 'label' column
        title=title
    )
    
    # Update layout for a cleaner look
    fig.update_traces(marker=dict(size=1))
    fig.update_layout(margin=dict(l=0, r=0, b=0, t=40))
    fig.show()

# %% [markdown]
# # Example of experiments

# %% [markdown]
# ## 1. Load & prepared the data
# WARNING: this step might be done with your data, so, just copy it from the previous lab if the dataset requires explicit preparation

# %%
df = pd.read_csv("pulsar.csv")

X_data = df.drop(columns="Class")
y_data = df["Class"]

df.head()
# Out:
#    Mean_Integrated         SD        EK  Skewness  Mean_DMSNR_Curve  \
# 0       140.562500  55.683782 -0.234571 -0.699648          3.199833
# 1       102.507812  58.882430  0.465318 -0.515088          1.677258
# 2       103.015625  39.341649  0.323328  1.051164          3.121237
# 3       136.750000  57.178449 -0.068415 -0.636238          3.642977
# 4        88.726562  40.672225  0.600866  1.123492          1.178930
#
#    SD_DMSNR_Curve  EK_DMSNR_Curve  Skewness_DMSNR_Curve  Class
# 0       19.110426        7.975532             74.242225      0
# 1       14.860146       10.576487            127.393580      0
# 2       21.744669        7.735822             63.171909      0
# 3       20.959280        6.896499             53.593661      0
# 4       11.468720       14.269573            252.567306      0

# %%
X_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17898 entries, 0 to 17897
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Mean_Integrated       17898 non-null  float64
#  1   SD                    17898 non-null  float64
#  2   EK                    17898 non-null  float64
#  3   Skewness              17898 non-null  float64
#  4   Mean_DMSNR_Curve      17898 non-null  float64
#  5   SD_DMSNR_Curve        17898 non-null  float64
#  6   EK_DMSNR_Curve        17898 non-null  float64
#  7   Skewness_DMSNR_Curve  17898 non-null  float64
# dtypes: float64(8)
# memory usage: 1.1 MB

# %%
X_data.describe() 

# CONCLUSION: based on the observed data this one require normalization
# so StandardScaler would be sufficient in this case
# Out:
#        Mean_Integrated            SD            EK      Skewness  \
# count     17898.000000  17898.000000  17898.000000  17898.000000
# mean        111.079968     46.549532      0.477857      1.770279
# std          25.652935      6.843189      1.064040      6.167913
# min           5.812500     24.772042     -1.876011     -1.791886
# 25%         100.929688     42.376018      0.027098     -0.188572
# 50%         115.078125     46.947479      0.223240      0.198710
# 75%         127.085938     51.023202      0.473325      0.927783
# max         192.617188     98.778911      8.069522     68.101622
#
#        Mean_DMSNR_Curve  SD_DMSNR_Curve  EK_DMSNR_Curve  Skewness_DMSNR_Curve
# count      17898.000000    17898.000000    17898.000000          17898.000000
# mean          12.614400       26.326515        8.303556            104.857709
# std           29.472897       19.470572        4.506092            106.514540
# ...

# %%
scaler = StandardScaler()

X_data = pd.DataFrame(
    data=scaler.fit_transform(X_data),
    columns=X_data.columns,
)

X_data.head()
# Out:
#    Mean_Integrated        SD        EK  Skewness  Mean_DMSNR_Curve  \
# 0         1.149317  1.334832 -0.669570 -0.400459         -0.319440
# 1        -0.334168  1.802265 -0.011785 -0.370535         -0.371102
# 2        -0.314372 -1.053322 -0.145233 -0.116593         -0.322107
# 3         1.000694  1.553254 -0.513409 -0.390178         -0.304404
# 4        -0.871402 -0.858879  0.115609 -0.104866         -0.388010
#
#    SD_DMSNR_Curve  EK_DMSNR_Curve  Skewness_DMSNR_Curve
# 0       -0.370625       -0.072798             -0.287438
# 1       -0.588924        0.504427              0.211581
# 2       -0.235328       -0.125996             -0.391373
# 3       -0.275666       -0.312265             -0.481300
# 4       -0.763111        1.324026              1.386794

# %%
X_data.describe()
# Out:
#        Mean_Integrated            SD            EK      Skewness  \
# count     1.789800e+04  1.789800e+04  1.789800e+04  1.789800e+04
# mean     -1.715021e-16 -3.398282e-16 -3.811158e-17 -1.270386e-17
# std       1.000028e+00  1.000028e+00  1.000028e+00  1.000028e+00
# min      -4.103640e+00 -3.182449e+00 -2.212262e+00 -5.775478e-01
# 25%      -3.956882e-01 -6.098955e-01 -4.236418e-01 -3.175961e-01
# 50%       1.558601e-01  5.815398e-02 -2.392997e-01 -2.548046e-01
# 75%       6.239604e-01  6.537588e-01 -4.259430e-03 -1.365972e-01
# max       3.178564e+00  7.632529e+00  7.134956e+00  1.075456e+01
#
#        Mean_DMSNR_Curve  SD_DMSNR_Curve  EK_DMSNR_Curve  Skewness_DMSNR_Curve
# count      1.789800e+04    1.789800e+04    1.789800e+04          1.789800e+04
# mean      -4.763947e-17    3.175965e-17    5.081544e-17          2.540772e-17
# std        1.000028e+00    1.000028e+00    1.000028e+00          1.000028e+00
# ...

# %% [markdown]
# ## 2. Do visualization with PCA only

# %%
pca_2c = PCA(n_components=2)
pca_3c = PCA(n_components=3)

pca_2c.fit(X_data)
pca_3c.fit(X_data)
# Out:
# PCA(n_components=3)

# %%
plot_2d(pca_2c.transform(X_data), y_data, title="Principal components")

# %%
plot_3d_plotly(pca_3c.transform(X_data), y_data, title="Principal components")

# %% [markdown]
# # Own experiments on the selected data

# %%
# TODO here you can create as many cell as you need
# TODO do your experiments here

# %% [markdown]
# # Conclusions

# %%
# TODO do your conclusions here as described in the work description
